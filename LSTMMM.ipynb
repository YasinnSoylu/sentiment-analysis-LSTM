# %% [markdown]
# <a href="https://colab.research.google.com/github/yasinsoylu1997/sentiment-analysis-LSTM/blob/main/LSTMMM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, GRU, Embedding, CuDNNGRU
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.keras.optimizers import Adam
import re
from sklearn.model_selection import train_test_split 
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk

from tensorflow.python.keras.preprocessing.sequence import pad_sequences

# %%
dataset = pd.read_csv('sample.csv')

# %%
dataset
# Out:
#        yildizSayisi  ... yorumLike
# 0                 1  ...         0
# 1                 1  ...         7
# 2                 1  ...         2
# 3                 1  ...         1
# 4                 1  ...         2
# ...             ...  ...       ...
# 49995             5  ...         0
# 49996             5  ...         0
# 49997             5  ...         0
# 49998             5  ...         0
# 49999             5  ...         0
#
# [50000 rows x 3 columns]

# %%
dataset.dropna()
# Out:
#        yildizSayisi  ... yorumLike
# 0                 1  ...         0
# 1                 1  ...         7
# 2                 1  ...         2
# 3                 1  ...         1
# 4                 1  ...         2
# ...             ...  ...       ...
# 49995             5  ...         0
# 49996             5  ...         0
# 49997             5  ...         0
# 49998             5  ...         0
# 49999             5  ...         0
#
# [50000 rows x 3 columns]

# %%
dataset["yildizSayisi"] = dataset.yildizSayisi.astype(float)

# %%
def sentiments(df):
  if df['yildizSayisi'] > 3.9:
    return 'Positive'
  elif df['yildizSayisi'] <= 3.0:
    return 'Negative'
dataset['sentiment'] = dataset.apply(sentiments, axis=1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yildizSayisi  50000 non-null  float64
#  1   yorum         50000 non-null  object
#  2   yorumLike     50000 non-null  int64
#  3   sentiment     50000 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.5+ MB

# %%
dataset
# Out:
#        yildizSayisi  ... sentiment
# 0               1.0  ...  Negative
# 1               1.0  ...  Negative
# 2               1.0  ...  Negative
# 3               1.0  ...  Negative
# 4               1.0  ...  Negative
# ...             ...  ...       ...
# 49995           5.0  ...  Positive
# 49996           5.0  ...  Positive
# 49997           5.0  ...  Positive
# 49998           5.0  ...  Positive
# 49999           5.0  ...  Positive
#
# [50000 rows x 4 columns]

# %%
dataset['yorum'] = dataset['yorum'].apply(lambda x: x.lower())

# %%
print(dataset[ dataset['sentiment'] == 'Positive'].size)
print(dataset[ dataset['sentiment'] == 'Negative'].size)
# Out:
# 80000
# 120000

# %%
data_pos = dataset[ dataset['sentiment'] == 'Positive']
data_pos = dataset['yorum']
data_neg = dataset[ dataset['sentiment'] == 'Negative']
data_neg = dataset['yorum']

# %%
def wordcloud_draw(dataset, color = 'black'):
    words = ' '.join(dataset)
    cleaned_word = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                            ])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color=color,
                      width=2500,
                      height=2000
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
data_pos.head()
# Out:
# 0    i̇lk ürünüm sorunsuz geldi lakin bunda prize t...
# 1    ürünü teslim aldığım günün ertesi iade için ka...
# 2    kesinlikle beğenmedim kullanmaya başladıktan 1...
# 3    merhaba ürün elime ulaştı ama ürün bir çalışıy...
# 4    kargo hızlı o konuda haksızlık yapamam ama ürü...
# Name: yorum, dtype: object

# %%
data_neg
# Out:
# 0        i̇lk ürünüm sorunsuz geldi lakin bunda prize t...
# 1        ürünü teslim aldığım günün ertesi iade için ka...
# 2        kesinlikle beğenmedim kullanmaya başladıktan 1...
# 3        merhaba ürün elime ulaştı ama ürün bir çalışıy...
# 4        kargo hızlı o konuda haksızlık yapamam ama ürü...
#                                ...
# 49995                çok güzel çok beğendim tafsiye ederim
# 49996    vallahi çok işime yaradı. aylarda öyle boşuna ...
# 49997    olması gerektigi gibi , kenarda hazırda beklem...
# 49998    arçelik bulaşık makinesi için aldım servis olm...
# 49999    fazladan koymuslar cok teşekkür ederim makınan...
# Name: yorum, Length: 50000, dtype: object

# %%
print("Positive words")
wordcloud_draw(data_pos,'white')
# Out:
# Positive words

# %%
print("Negative words")
wordcloud_draw(data_neg)
# Out:
# Negative words

# %%
dataset
# Out:
#        yildizSayisi  ... sentiment
# 0               1.0  ...  Negative
# 1               1.0  ...  Negative
# 2               1.0  ...  Negative
# 3               1.0  ...  Negative
# 4               1.0  ...  Negative
# ...             ...  ...       ...
# 49995           5.0  ...  Positive
# 49996           5.0  ...  Positive
# 49997           5.0  ...  Positive
# 49998           5.0  ...  Positive
# 49999           5.0  ...  Positive
#
# [50000 rows x 4 columns]

# %%
data = dataset[['yorum','sentiment']]
target = dataset['sentiment'].values

# %%
data
# Out:
#                                                    yorum sentiment
# 0      i̇lk ürünüm sorunsuz geldi lakin bunda prize t...  Negative
# 1      ürünü teslim aldığım günün ertesi iade için ka...  Negative
# 2      kesinlikle beğenmedim kullanmaya başladıktan 1...  Negative
# 3      merhaba ürün elime ulaştı ama ürün bir çalışıy...  Negative
# 4      kargo hızlı o konuda haksızlık yapamam ama ürü...  Negative
# ...                                                  ...       ...
# 49995              çok güzel çok beğendim tafsiye ederim  Positive
# 49996  vallahi çok işime yaradı. aylarda öyle boşuna ...  Positive
# 49997  olması gerektigi gibi , kenarda hazırda beklem...  Positive
# 49998  arçelik bulaşık makinesi için aldım servis olm...  Positive
# 49999  fazladan koymuslar cok teşekkür ederim makınan...  Positive
#
# [50000 rows x 2 columns]

# %%
data['yorum'] = data['yorum'].apply(lambda x: x.lower())
data['yorum'] = data['yorum'].apply((lambda x: re.sub('[^a-zA-z0-9\s]','',x)))

print(data[ data['sentiment'] == 'Positive'].size)
print(data[ data['sentiment'] == 'Negative'].size)

for idx,row in data.iterrows():
    row[0] = row[0].replace('rt',' ')
    
max_fatures = 2000
tokenizer = Tokenizer(num_words=max_fatures, split=' ')
tokenizer.fit_on_texts(data['yorum'].values)
X = tokenizer.texts_to_sequences(data['yorum'].values)
X = pad_sequences(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 40000
# 60000

# %%
num_words = 10000
tokenizer = Tokenizer(num_words=num_words)

# %%
cutoff = int(len(data) * 0.80)
x_train, x_test = data[:cutoff], data[cutoff:]
y_train, y_test = target[:cutoff], target[cutoff:]

# %%
num_words = 10000
tokenizer = Tokenizer(num_words=num_words)

# %%
tokenizer.fit_on_texts(data)
x_train_tokens = tokenizer.texts_to_sequences(x_train)

# %%
tokenizer.fit_on_texts(data)
x_test_tokens = tokenizer.texts_to_sequences(x_test)

# %%
num_tokens = [len(tokens) for tokens in x_train_tokens + x_test_tokens]
num_tokens = np.array(num_tokens)

# %%
max_tokens = np.mean(num_tokens) + 2 * np.std(num_tokens)
max_tokens = int(max_tokens)
max_tokens
# Out:
# 1

# %%
x_train_pad = pad_sequences(x_train_tokens, maxlen=max_tokens)

x_test_pad = pad_sequences(x_test_tokens, maxlen=max_tokens)

# %%
x_train_tokens = tokenizer.texts_to_sequences(x_train)

# %%
x_test_tokens = tokenizer.texts_to_sequences(x_test)

# %%
idx = tokenizer.word_index
inverse_map = dict(zip(idx.values(), idx.keys()))

# %%
def tokens_to_string(tokens):
    words = [inverse_map[token] for token in tokens if token!=0]
    text = ' '.join(words)
    return text

# %%
from tensorflow.keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Embedding, Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout , LSTM, SpatialDropout1D
from keras.metrics import Precision, Recall
from tensorflow.keras.optimizers import  RMSprop
from keras import datasets
from keras.callbacks import LearningRateScheduler
from keras.callbacks import History
from keras import losses

# %%
max_len=177

model = Sequential()
embedding_size = 50

model.add(Embedding(input_dim=num_words,
                    output_dim=embedding_size,
                    input_length=max_len,
                    name='embedding_layer'))

model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(32))
model.add(Dropout(0.5))
model.add(Dense(2, activation='sigmoid'))

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy', Precision(), Recall()])

# %%
Y = pd.get_dummies(data['sentiment']).values
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.3, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (35000, 177) (35000, 2)
# (15000, 177) (15000, 2)

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=5)

# %%
history=model.fit(X_train, Y_train, epochs=50, batch_size=512,validation_split=0.1,callbacks=[callback])
# Out:
# Epoch 1/50
# 62/62 [==============================] - 2s 33ms/step - loss: 0.0963 - accuracy: 0.9653 - precision: 0.9651 - recall: 0.9654 - val_loss: 0.9695 - val_accuracy: 0.7983 - val_precision: 0.7989 - val_recall: 0.7977
# Epoch 2/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0941 - accuracy: 0.9653 - precision: 0.9651 - recall: 0.9654 - val_loss: 0.9896 - val_accuracy: 0.8014 - val_precision: 0.8010 - val_recall: 0.8017
# Epoch 3/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0897 - accuracy: 0.9678 - precision: 0.9679 - recall: 0.9678 - val_loss: 1.0074 - val_accuracy: 0.8014 - val_precision: 0.8016 - val_recall: 0.8011
# Epoch 4/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0851 - accuracy: 0.9686 - precision: 0.9682 - recall: 0.9686 - val_loss: 1.0658 - val_accuracy: 0.7963 - val_precision: 0.7965 - val_recall: 0.7960
# Epoch 5/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0923 - accuracy: 0.9662 - precision: 0.9660 - recall: 0.9662 - val_loss: 1.0660 - val_accuracy: 0.8057 - val_precision: 0.8048 - val_recall: 0.8057
# Epoch 6/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0943 - accuracy: 0.9644 - precision: 0.9640 - recall: 0.9645 - val_loss: 1.0515 - val_accuracy: 0.8003 - val_precision: 0.8010 - val_recall: 0.7994
# Epoch 7/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0858 - accuracy: 0.9684 - precision: 0.9683 - recall: 0.9683 - val_loss: 1.1090 - val_accuracy: 0.7980 - val_precision: 0.7982 - val_recall: 0.7977
# Epoch 8/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0867 - accuracy: 0.9676 - precision: 0.9676 - recall: 0.9678 - val_loss: 1.0882 - val_accuracy: 0.7971 - val_precision: 0.7976 - val_recall: 0.7971
# Epoch 9/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0780 - accuracy: 0.9709 - precision: 0.9708 - recall: 0.9708 - val_loss: 1.1073 - val_accuracy: 0.8006 - val_precision: 0.8002 - val_recall: 0.8000
# Epoch 10/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0758 - accuracy: 0.9719 - precision: 0.9717 - recall: 0.9721 - val_loss: 1.1490 - val_accuracy: 0.8000 - val_precision: 0.8005 - val_recall: 0.8000
# Epoch 11/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0727 - accuracy: 0.9734 - precision: 0.9733 - recall: 0.9735 - val_loss: 1.1902 - val_accuracy: 0.7974 - val_precision: 0.7969 - val_recall: 0.7971
# Epoch 12/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0704 - accuracy: 0.9739 - precision: 0.9738 - recall: 0.9742 - val_loss: 1.2040 - val_accuracy: 0.7886 - val_precision: 0.7883 - val_recall: 0.7883
# Epoch 13/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0691 - accuracy: 0.9739 - precision: 0.9738 - recall: 0.9740 - val_loss: 1.2283 - val_accuracy: 0.7934 - val_precision: 0.7931 - val_recall: 0.7931
# Epoch 14/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0689 - accuracy: 0.9741 - precision: 0.9740 - recall: 0.9740 - val_loss: 1.2571 - val_accuracy: 0.7920 - val_precision: 0.7922 - val_recall: 0.7920
# Epoch 15/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0731 - accuracy: 0.9721 - precision: 0.9722 - recall: 0.9722 - val_loss: 1.2409 - val_accuracy: 0.7963 - val_precision: 0.7969 - val_recall: 0.7957
# Epoch 16/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0869 - accuracy: 0.9669 - precision: 0.9668 - recall: 0.9670 - val_loss: 1.1770 - val_accuracy: 0.7997 - val_precision: 0.7997 - val_recall: 0.7994
# Epoch 17/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0867 - accuracy: 0.9673 - precision: 0.9671 - recall: 0.9671 - val_loss: 1.2070 - val_accuracy: 0.8051 - val_precision: 0.8055 - val_recall: 0.8049
# Epoch 18/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0723 - accuracy: 0.9727 - precision: 0.9726 - recall: 0.9726 - val_loss: 1.1966 - val_accuracy: 0.7954 - val_precision: 0.7961 - val_recall: 0.7954
# Epoch 19/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0666 - accuracy: 0.9747 - precision: 0.9745 - recall: 0.9747 - val_loss: 1.2504 - val_accuracy: 0.7980 - val_precision: 0.7980 - val_recall: 0.7980
# Epoch 20/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0626 - accuracy: 0.9761 - precision: 0.9760 - recall: 0.9761 - val_loss: 1.2987 - val_accuracy: 0.7991 - val_precision: 0.7994 - val_recall: 0.7994
# Epoch 21/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0606 - accuracy: 0.9771 - precision: 0.9769 - recall: 0.9771 - val_loss: 1.3177 - val_accuracy: 0.7966 - val_precision: 0.7963 - val_recall: 0.7966
# Epoch 22/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0589 - accuracy: 0.9774 - precision: 0.9773 - recall: 0.9776 - val_loss: 1.3510 - val_accuracy: 0.7949 - val_precision: 0.7944 - val_recall: 0.7949
# Epoch 23/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0586 - accuracy: 0.9772 - precision: 0.9769 - recall: 0.9774 - val_loss: 1.3611 - val_accuracy: 0.7954 - val_precision: 0.7957 - val_recall: 0.7954
# Epoch 24/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0572 - accuracy: 0.9783 - precision: 0.9781 - recall: 0.9783 - val_loss: 1.4141 - val_accuracy: 0.7983 - val_precision: 0.7989 - val_recall: 0.7991
# Epoch 25/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0559 - accuracy: 0.9788 - precision: 0.9785 - recall: 0.9789 - val_loss: 1.4182 - val_accuracy: 0.7937 - val_precision: 0.7935 - val_recall: 0.7937
# Epoch 26/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0552 - accuracy: 0.9786 - precision: 0.9785 - recall: 0.9789 - val_loss: 1.4443 - val_accuracy: 0.7931 - val_precision: 0.7927 - val_recall: 0.7934
# Epoch 27/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0547 - accuracy: 0.9786 - precision: 0.9782 - recall: 0.9789 - val_loss: 1.4705 - val_accuracy: 0.7911 - val_precision: 0.7910 - val_recall: 0.7914
# Epoch 28/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0528 - accuracy: 0.9795 - precision: 0.9794 - recall: 0.9796 - val_loss: 1.4975 - val_accuracy: 0.7926 - val_precision: 0.7931 - val_recall: 0.7929
# Epoch 29/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0526 - accuracy: 0.9795 - precision: 0.9794 - recall: 0.9796 - val_loss: 1.5109 - val_accuracy: 0.7897 - val_precision: 0.7902 - val_recall: 0.7897
# Epoch 30/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0547 - accuracy: 0.9783 - precision: 0.9783 - recall: 0.9784 - val_loss: 1.4874 - val_accuracy: 0.7894 - val_precision: 0.7894 - val_recall: 0.7894
# Epoch 31/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0554 - accuracy: 0.9782 - precision: 0.9780 - recall: 0.9783 - val_loss: 1.5172 - val_accuracy: 0.7951 - val_precision: 0.7949 - val_recall: 0.7951
# Epoch 32/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0593 - accuracy: 0.9771 - precision: 0.9770 - recall: 0.9772 - val_loss: 1.4884 - val_accuracy: 0.7940 - val_precision: 0.7933 - val_recall: 0.7940
# Epoch 33/50
# 62/62 [==============================] - 2s 30ms/step - loss: 0.0684 - accuracy: 0.9743 - precision: 0.9744 - recall: 0.9741 - val_loss: 1.4186 - val_accuracy: 0.7889 - val_precision: 0.7889 - val_recall: 0.7889
# Epoch 34/50
# 62/62 [==============================] - 2s 31ms/step - loss: 0.0771 - accuracy: 0.9705 - precision: 0.9707 - recall: 0.9705 - val_loss: 1.3907 - val_accuracy: 0.7974 - val_precision: 0.7981 - val_recall: 0.7974

# %%
 score = model.evaluate(X_test, Y_test,batch_size=512)
# Out:
# 30/30 [==============================] - 0s 14ms/step - loss: 1.5036 - accuracy: 0.7871 - precision: 0.7873 - recall: 0.7866

# %%
print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.503630518913269
# Test accuracy: 0.787066638469696
